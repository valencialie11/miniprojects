# %%
import pandas as pd

# %%
df = pd.read_csv("randomstrs.csv")

# %%
df
# Out:
#      #>M[OaL.l`
# 0       hg=<z!9
# 1             y
# 2    Vv>;vdWS66
# 3          3u=v
# 4          %8Q%
# ..          ...
# 195         x>i
# 196     [=y(w]|
# 197           \
# 198        )'3w
# 199   WLW0~plul
#
# [200 rows x 1 columns]

# %%
df = df.rename(columns={'#>M[OaL.l`': 'random strings'})

# %%
series = df.T.squeeze()

# %%
series
# Out:
# 0         hg=<z!9
# 1               y
# 2      Vv>;vdWS66
# 3            3u=v
# 4            %8Q%
#           ...
# 195           x>i
# 196       [=y(w]|
# 197             \
# 198          )'3w
# 199     WLW0~plul
# Name: random strings, Length: 200, dtype: object

# %%
mlist = list(series)

# %%
def split(word):
    return [char for char in word]

split(mlist)
# Out:
# ['hg=<z!9',
#  'y',
#  'Vv>;vdWS66',
#  '3u=v',
#  '%8Q%',
#  'G{rG',
#  'we(]qe',
#  nan,
#  'Z',
#  'KwvS~Z5',
#  'wG8jH/d;',
#  'FH2~PGGH',
#  nan,
#  '1',
#  '=Z',
#  'WUAt',
#  '7PNv',
#  's#,',
#  'sc',
#  '(0(]2di',
#  'tQ5(aKl[!D',
#  'L',
#  'V`fr.',
#  'GFx|Eegq,',
#  'FiEua',
#  'a^S',
#  '#mka IF',
#  'WHm&XL%sr',
#  '=',
#  'L~QQ&ivZz',
#  'Zpa!f>9',
#  'al',
#  '#)]',
#  "'p]7}`>6=/",
#  'jL',
#  '33=y-<[OR',
#  '<g|9)hG*',
#  'p-',
#  '0f_h@',
#  'LlujRz|j^',
#  nan,
#  'FO`gbANRk',
#  'p+fg{41^r',
#  '(X?c4Uy',
#  'F?t\\lNz\\;d',
#  "7WY%0{Wi'}",
#  'd>*wCk@o',
#  'e=Y~K) i=^',
#  ']AL7',
#  'yU3',
#  '/',
#  '+Sc;XmOP',
#  nan,
#  'Qq ;-\\)x',
#  '{1RY![',
#  'zdpC&n',
#  'Y{3 w',
#  'l3x+zJ ',
#  '}yU',
#  '$za@',
#  '*"',
#  'REl',
#  'tHuh)hYIxC',
#  '!~L<K%',
#  'xX14&-5FEG',
#  'ugT5lB',
#  'ok10B',
#  'iivk9H',
#  nan,
#  'g,f',
#  '{',
#  'k\\S8mTJ',
#  '7!G^',
#  'A',
#  '{T',
#  "R'0n^",
#  '~%',
#  '5D',
#  'WGx=',
#  ':(',
#  '4',
#  nan,
#  '$q',
# ...
